# %% [markdown]
# # 📊 Customer Sentiment Analysis - iPhone 15 128GB
#
# **Objective**: Analyze customer sentiment using reviews from Flipkart for the iPhone 15 128GB model using scraping, preprocessing, sentiment classification, and visualization.

# %%
#DATA COLLECTION (WEB SCRAPING)
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from selenium import webdriver
from bs4 import BeautifulSoup
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
import nltk
from textblob import TextBlob
import requests
import re


#START CHROME WEBDRIVER
driver = webdriver.Chrome()

# %% [markdown]
# ## 📥 Data Loading

# %%
# INITIALIZE LISTS TO STORE DATA
name=[]
rating=[]
review=[]
City = []
#FLIPKART PRODUCT REVIEWS URL
url = """https://www.flipkart.com/apple-iphone-15-blue-128-gb/product-reviews/itmbf14ef54f645d?pid=MOBGTAGPAQNVFZZY&lid=LSTMOBGTAGPAQNVFZZY7RHDU7&marketplace=FLIPKART"""
#SCRAPE MULTIPLE PAGES
for i in range(1,5):
    new_url = url + "&page=" +str(i)
    r = requests.get(new_url)
    soup = BeautifulSoup(r.text , "html.parser")
#EXTRACTING NAMES
    names = soup.find_all("p" , {"class" : "_2NsDsF AwS1CA"})
    for i in names:
        name.append(i.text)
    name
#EXTRACTING RATINGS
    ratings = soup.find_all("div" , {"class" : "XQDdHH Ga3i8K"})
    for i in ratings:
        rating.append(i.text)
    rating
#EXTRACTING REVIEWS
    reviews = soup.find_all("div" , {"class" : "ZmyHeo"})
    for i in reviews:
        review.append(i.text)
    review

            
print(len(name) , len(review) , len(rating))
# Out:
# 30 30 30

# %% [markdown]
# ## 📊 Data Exploration

# %%
df = pd.DataFrame({"CUSTOMER NAME" : name , "RATING" : rating , "REVIEW" : review})
df
# Out:
#             CUSTOMER NAME RATING  \
# 0          bijaya mohanty      5
# 1                  Ajin V      5
# 2            Rahul Shedge      5
# 3        Mousam  Guha Roy      4
# 4            Nikhil Kumar      5
# 5         Prithivi Boruah      5
# 6       Flipkart Customer      5
# 7            Rishabh  Jha      5
# 8            Akshay Meena      5
# 9      Arunji Govindaraju      5
# 10      CHETAN  TILWALIA       5
# 11  VinodKUMAR VinodKUMAR      4
# 12  Varsha Sadanand Salve      5
# 13          Ankit  Verma       4
# 14      Flipkart Customer      5
# 15             Suman Jain      5
# 16        Anubhav Chauhan      5
# 17          Praveen Kumar      5
# 18           Zeeshan Khan      5
# 19      Flipkart Customer      4
# 20            Dev  Kumar       5
# 21              SONAL PAL      5
# 22     Shubhanker  Singh       5
# 23           Jayanta  Roy      5
# 24            Nitin Kumar      5
# 25            Jayanth Jai      5
# 26              Sajib Das      5
# 27            Akash  Deep      5
# 28         Bhaskar Sharma      5
# 29      Flipkart Customer      5
#
#                                                REVIEW
# 0   Just go for it.Amazing one.Beautiful camera wi...
# 1                       High quality camera😍READ MORE
# 2   Totally happy!Camera 5Battery 5 Display 5Desig...
# 3                                  Very niceREAD MORE
# 4   Switch from OnePlus to iPhone I am stunned wit...
# 5       Camera Quality Is Improved Loving ItREAD MORE
# 6   Awesome photography experience. Battery backup...
# 7                               Awesome 🔥🔥☺️READ MORE
# 8   So beautiful, so elegant, just a vowww😍❤️READ ...
# 9   Awesome product very happy to hold this. Bette...
# 10                                    Nice 👌READ MORE
# 11                           Nice phone goodREAD MORE
# 12  The iPhone 15 exceeded my expectations in ever...
# 13      Awesome camra quality superb camra 😊READ MORE
# 14  Using this Iphone 15 from 1month and it has be...
# 15                          Simply Awesome 🤩READ MORE
# 16  I have recently switched from Android to ios, ...
# 17  This is my first iphone ever used loving it al...
# 18  Awesome quality I am very happy. Thank you Fli...
# 19                              Nice productREAD MORE
# 20                Camera quality top notch 👍READ MORE
# 21  Awesome phone powerful performance and battery...
# 22                    Simply wow wow wow 😍❤️READ MORE
# 23                                Nice 🙂🙂🙂🙂🙂READ MORE
# 24                   Very nice product 👌👌👌👌👌READ MORE
# 25  Their is nothing to explain about Apple iPhone...
# 26  moving from android to apple is a surreal expe...
# 27  Camera is just wow. All classes clicks are don...
# 28                                   AwesomeREAD MORE
# 29                                  Camera 🔥READ MORE

# %% [markdown]
# ## 🧹 Data Cleaning

# %%
#DATA CLEANING
df["CUSTOMER NAME"] = df["CUSTOMER NAME"].str.title()
df["REVIEW"]= df["REVIEW"].str.replace("READ MORE" , "")
df
# Out:
#             CUSTOMER NAME RATING  \
# 0          Bijaya Mohanty      5
# 1                  Ajin V      5
# 2            Rahul Shedge      5
# 3        Mousam  Guha Roy      4
# 4            Nikhil Kumar      5
# 5         Prithivi Boruah      5
# 6       Flipkart Customer      5
# 7            Rishabh  Jha      5
# 8            Akshay Meena      5
# 9      Arunji Govindaraju      5
# 10      Chetan  Tilwalia       5
# 11  Vinodkumar Vinodkumar      4
# 12  Varsha Sadanand Salve      5
# 13          Ankit  Verma       4
# 14      Flipkart Customer      5
# 15             Suman Jain      5
# 16        Anubhav Chauhan      5
# 17          Praveen Kumar      5
# 18           Zeeshan Khan      5
# 19      Flipkart Customer      4
# 20            Dev  Kumar       5
# 21              Sonal Pal      5
# 22     Shubhanker  Singh       5
# 23           Jayanta  Roy      5
# 24            Nitin Kumar      5
# 25            Jayanth Jai      5
# 26              Sajib Das      5
# 27            Akash  Deep      5
# 28         Bhaskar Sharma      5
# 29      Flipkart Customer      5
#
#                                                REVIEW
# 0   Just go for it.Amazing one.Beautiful camera wi...
# 1                                High quality camera😍
# 2   Totally happy!Camera 5Battery 5 Display 5Design 5
# 3                                           Very nice
# 4   Switch from OnePlus to iPhone I am stunned wit...
# 5                Camera Quality Is Improved Loving It
# 6   Awesome photography experience. Battery backup...
# 7                                        Awesome 🔥🔥☺️
# 8           So beautiful, so elegant, just a vowww😍❤️
# 9   Awesome product very happy to hold this. Bette...
# 10                                             Nice 👌
# 11                                    Nice phone good
# 12  The iPhone 15 exceeded my expectations in ever...
# 13               Awesome camra quality superb camra 😊
# 14  Using this Iphone 15 from 1month and it has be...
# 15                                   Simply Awesome 🤩
# 16  I have recently switched from Android to ios, ...
# 17  This is my first iphone ever used loving it al...
# 18  Awesome quality I am very happy. Thank you Fli...
# 19                                       Nice product
# 20                         Camera quality top notch 👍
# 21  Awesome phone powerful performance and battery...
# 22                             Simply wow wow wow 😍❤️
# 23                                         Nice 🙂🙂🙂🙂🙂
# 24                            Very nice product 👌👌👌👌👌
# 25  Their is nothing to explain about Apple iPhone...
# 26  moving from android to apple is a surreal expe...
# 27  Camera is just wow. All classes clicks are don...
# 28                                            Awesome
# 29                                           Camera 🔥

# %% [markdown]
# ## 📝 Text Preprocessing

# %%
def split_into_sentences(text):
    if not isinstance(text, str):
        return []
    return re.findall(r'[^.!?]+[.!?]', text)

# Apply the function
df["REVIEW1"] = df["REVIEW"].apply(split_into_sentences)
df
# Out:
#             CUSTOMER NAME RATING  \
# 0          Bijaya Mohanty      5
# 1                  Ajin V      5
# 2            Rahul Shedge      5
# 3        Mousam  Guha Roy      4
# 4            Nikhil Kumar      5
# 5         Prithivi Boruah      5
# 6       Flipkart Customer      5
# 7            Rishabh  Jha      5
# 8            Akshay Meena      5
# 9      Arunji Govindaraju      5
# 10      Chetan  Tilwalia       5
# 11  Vinodkumar Vinodkumar      4
# 12  Varsha Sadanand Salve      5
# 13          Ankit  Verma       4
# 14      Flipkart Customer      5
# 15             Suman Jain      5
# 16        Anubhav Chauhan      5
# 17          Praveen Kumar      5
# 18           Zeeshan Khan      5
# 19      Flipkart Customer      4
# 20            Dev  Kumar       5
# 21              Sonal Pal      5
# 22     Shubhanker  Singh       5
# 23           Jayanta  Roy      5
# 24            Nitin Kumar      5
# 25            Jayanth Jai      5
# 26              Sajib Das      5
# 27            Akash  Deep      5
# 28         Bhaskar Sharma      5
# 29      Flipkart Customer      5
#
#                                                REVIEW  \
# 0   Just go for it.Amazing one.Beautiful camera wi...
# 1                                High quality camera😍
# 2   Totally happy!Camera 5Battery 5 Display 5Design 5
# 3                                           Very nice
# 4   Switch from OnePlus to iPhone I am stunned wit...
# 5                Camera Quality Is Improved Loving It
# 6   Awesome photography experience. Battery backup...
# 7                                        Awesome 🔥🔥☺️
# 8           So beautiful, so elegant, just a vowww😍❤️
# 9   Awesome product very happy to hold this. Bette...
# 10                                             Nice 👌
# 11                                    Nice phone good
# 12  The iPhone 15 exceeded my expectations in ever...
# 13               Awesome camra quality superb camra 😊
# 14  Using this Iphone 15 from 1month and it has be...
# 15                                   Simply Awesome 🤩
# 16  I have recently switched from Android to ios, ...
# 17  This is my first iphone ever used loving it al...
# 18  Awesome quality I am very happy. Thank you Fli...
# 19                                       Nice product
# 20                         Camera quality top notch 👍
# 21  Awesome phone powerful performance and battery...
# 22                             Simply wow wow wow 😍❤️
# 23                                         Nice 🙂🙂🙂🙂🙂
# 24                            Very nice product 👌👌👌👌👌
# 25  Their is nothing to explain about Apple iPhone...
# 26  moving from android to apple is a surreal expe...
# 27  Camera is just wow. All classes clicks are don...
# 28                                            Awesome
# 29                                           Camera 🔥
#
#                                               REVIEW1
# 0                     [Just go for it., Amazing one.]
# 1                                                  []
# 2                                    [Totally happy!]
# 3                                                  []
# 4   [Switch from OnePlus to iPhone I am stunned wi...
# 5                                                  []
# 6   [Awesome photography experience.,  Battery bac...
# 7                                                  []
# 8                                                  []
# 9   [Awesome product very happy to hold this.,  Be...
# 10                                                 []
# 11                                                 []
# 12  [The iPhone 15 exceeded my expectations in eve...
# 13                                                 []
# 14                                                 []
# 15                                                 []
# 16  [I have recently switched from Android to ios,...
# 17                                                 []
# 18  [Awesome quality I am very happy.,  Thank you ...
# 19                                                 []
# 20                                                 []
# 21                                                 []
# 22                                                 []
# 23                                                 []
# 24                                                 []
# 25                                                 []
# 26  [moving from android to apple is a surreal exp...
# 27  [Camera is just wow.,  All classes clicks are ...
# 28                                                 []
# 29                                                 []

# %% [markdown]
# ## 🧠 Sentiment Analysis

# %%
import pandas as pd
from textblob import blob
def get_polarity(sentences):
    return [TextBlob(sentence).sentiment.polarity for sentence in sentences]
df["Polarity"] = df["REVIEW1"].apply(get_polarity)
df
df["Subjectivity"] = df["REVIEW"].apply(lambda x : TextBlob(x).sentiment.subjectivity)
df
# Out:
#             CUSTOMER NAME RATING  \
# 0          Bijaya Mohanty      5
# 1                  Ajin V      5
# 2            Rahul Shedge      5
# 3        Mousam  Guha Roy      4
# 4            Nikhil Kumar      5
# 5         Prithivi Boruah      5
# 6       Flipkart Customer      5
# 7            Rishabh  Jha      5
# 8            Akshay Meena      5
# 9      Arunji Govindaraju      5
# 10      Chetan  Tilwalia       5
# 11  Vinodkumar Vinodkumar      4
# 12  Varsha Sadanand Salve      5
# 13          Ankit  Verma       4
# 14      Flipkart Customer      5
# 15             Suman Jain      5
# 16        Anubhav Chauhan      5
# 17          Praveen Kumar      5
# 18           Zeeshan Khan      5
# 19      Flipkart Customer      4
# 20            Dev  Kumar       5
# 21              Sonal Pal      5
# 22     Shubhanker  Singh       5
# 23           Jayanta  Roy      5
# 24            Nitin Kumar      5
# 25            Jayanth Jai      5
# 26              Sajib Das      5
# 27            Akash  Deep      5
# 28         Bhaskar Sharma      5
# 29      Flipkart Customer      5
#
#                                                REVIEW  \
# 0   Just go for it.Amazing one.Beautiful camera wi...
# 1                                High quality camera😍
# 2   Totally happy!Camera 5Battery 5 Display 5Design 5
# 3                                           Very nice
# 4   Switch from OnePlus to iPhone I am stunned wit...
# 5                Camera Quality Is Improved Loving It
# 6   Awesome photography experience. Battery backup...
# 7                                        Awesome 🔥🔥☺️
# 8           So beautiful, so elegant, just a vowww😍❤️
# 9   Awesome product very happy to hold this. Bette...
# 10                                             Nice 👌
# 11                                    Nice phone good
# 12  The iPhone 15 exceeded my expectations in ever...
# 13               Awesome camra quality superb camra 😊
# 14  Using this Iphone 15 from 1month and it has be...
# 15                                   Simply Awesome 🤩
# 16  I have recently switched from Android to ios, ...
# 17  This is my first iphone ever used loving it al...
# 18  Awesome quality I am very happy. Thank you Fli...
# 19                                       Nice product
# 20                         Camera quality top notch 👍
# 21  Awesome phone powerful performance and battery...
# 22                             Simply wow wow wow 😍❤️
# 23                                         Nice 🙂🙂🙂🙂🙂
# 24                            Very nice product 👌👌👌👌👌
# 25  Their is nothing to explain about Apple iPhone...
# 26  moving from android to apple is a surreal expe...
# 27  Camera is just wow. All classes clicks are don...
# 28                                            Awesome
# 29                                           Camera 🔥
#
#                                               REVIEW1  \
# 0                     [Just go for it., Amazing one.]
# 1                                                  []
# 2                                    [Totally happy!]
# 3                                                  []
# 4   [Switch from OnePlus to iPhone I am stunned wi...
# 5                                                  []
# 6   [Awesome photography experience.,  Battery bac...
# 7                                                  []
# 8                                                  []
# 9   [Awesome product very happy to hold this.,  Be...
# 10                                                 []
# 11                                                 []
# 12  [The iPhone 15 exceeded my expectations in eve...
# 13                                                 []
# 14                                                 []
# 15                                                 []
# 16  [I have recently switched from Android to ios,...
# 17                                                 []
# 18  [Awesome quality I am very happy.,  Thank you ...
# 19                                                 []
# 20                                                 []
# 21                                                 []
# 22                                                 []
# 23                                                 []
# 24                                                 []
# 25                                                 []
# 26  [moving from android to apple is a surreal exp...
# 27  [Camera is just wow.,  All classes clicks are ...
# 28                                                 []
# 29                                                 []
#
#                                           Polarity  Subjectivity
# 0                        [0.0, 0.6000000000000001]      0.633333
# 1                                               []      0.540000
# 2                                            [1.0]      0.750000
# 3                                               []      1.000000
# 4                                       [0.0, 1.0]      1.000000
# 5                                               []      0.950000
# 6                                  [1.0, 0.7, 0.5]      0.700000
# 7                                               []      1.000000
# 8                                               []      1.000000
# 9   [1.0, 0.5, 0.5, 0.0, -0.1, 0.6666666666666666]      0.557407
# 10                                              []      1.000000
# 11                                              []      0.800000
# 12                       [0.0, 0.5, 0.9, 0.5, 0.5]      0.792857
# 13                                              []      1.000000
# 14                                              []      0.300000
# 15                                              []      1.000000
# 16                [0.23833333333333337, 0.78, 0.5]      0.689000
# 17                                              []      0.461111
# 18                                      [1.0, 0.0]      1.000000
# 19                                              []      1.000000
# 20                                              []      0.500000
# 21                                              []      0.926667
# 22                                              []      1.000000
# 23                                              []      1.000000
# 24                                              []      1.000000
# 25                                              []      0.900000
# 26                                     [0.25, 0.5]      0.750000
# 27                            [0.1, 0.0, 1.0, 0.0]      0.733333
# 28                                              []      1.000000
# 29                                              []      0.000000

# %%
from statistics import mean
def calculate_average_polarity(polarities):
    return mean(polarities) if polarities else 0
df["Average_Polarity"] = df["Polarity"].apply(calculate_average_polarity)
df.head(10)
# Out:
#         CUSTOMER NAME RATING  \
# 0      Bijaya Mohanty      5
# 1              Ajin V      5
# 2        Rahul Shedge      5
# 3    Mousam  Guha Roy      4
# 4        Nikhil Kumar      5
# 5     Prithivi Boruah      5
# 6   Flipkart Customer      5
# 7        Rishabh  Jha      5
# 8        Akshay Meena      5
# 9  Arunji Govindaraju      5
#
#                                               REVIEW  \
# 0  Just go for it.Amazing one.Beautiful camera wi...
# 1                               High quality camera😍
# 2  Totally happy!Camera 5Battery 5 Display 5Design 5
# 3                                          Very nice
# 4  Switch from OnePlus to iPhone I am stunned wit...
# 5               Camera Quality Is Improved Loving It
# 6  Awesome photography experience. Battery backup...
# 7                                       Awesome 🔥🔥☺️
# 8          So beautiful, so elegant, just a vowww😍❤️
# 9  Awesome product very happy to hold this. Bette...
#
#                                              REVIEW1  \
# 0                    [Just go for it., Amazing one.]
# 1                                                 []
# 2                                   [Totally happy!]
# 3                                                 []
# 4  [Switch from OnePlus to iPhone I am stunned wi...
# 5                                                 []
# 6  [Awesome photography experience.,  Battery bac...
# 7                                                 []
# 8                                                 []
# 9  [Awesome product very happy to hold this.,  Be...
#
#                                          Polarity  Subjectivity  \
# 0                       [0.0, 0.6000000000000001]      0.633333
# 1                                              []      0.540000
# 2                                           [1.0]      0.750000
# 3                                              []      1.000000
# 4                                      [0.0, 1.0]      1.000000
# 5                                              []      0.950000
# 6                                 [1.0, 0.7, 0.5]      0.700000
# 7                                              []      1.000000
# 8                                              []      1.000000
# 9  [1.0, 0.5, 0.5, 0.0, -0.1, 0.6666666666666666]      0.557407
#
#    Average_Polarity
# 0          0.300000
# 1          0.000000
# 2          1.000000
# 3          0.000000
# 4          0.500000
# 5          0.000000
# 6          0.733333
# 7          0.000000
# 8          0.000000
# 9          0.427778

# %%
def sentiment(pol):
    if pol >= 0.75:
        return "Extremely Positive"
    elif pol > 0:
        return "Positive"
    elif pol == 0:
        return "Neutral"
    elif pol <= -0.75:
        return "Negative"
    else :
        return "Extremely Negative"
df["Sentiment"]=df["Average_Polarity"].apply(sentiment)
df
# Out:
#             CUSTOMER NAME RATING  \
# 0          Bijaya Mohanty      5
# 1                  Ajin V      5
# 2            Rahul Shedge      5
# 3        Mousam  Guha Roy      4
# 4            Nikhil Kumar      5
# 5         Prithivi Boruah      5
# 6       Flipkart Customer      5
# 7            Rishabh  Jha      5
# 8            Akshay Meena      5
# 9      Arunji Govindaraju      5
# 10      Chetan  Tilwalia       5
# 11  Vinodkumar Vinodkumar      4
# 12  Varsha Sadanand Salve      5
# 13          Ankit  Verma       4
# 14      Flipkart Customer      5
# 15             Suman Jain      5
# 16        Anubhav Chauhan      5
# 17          Praveen Kumar      5
# 18           Zeeshan Khan      5
# 19      Flipkart Customer      4
# 20            Dev  Kumar       5
# 21              Sonal Pal      5
# 22     Shubhanker  Singh       5
# 23           Jayanta  Roy      5
# 24            Nitin Kumar      5
# 25            Jayanth Jai      5
# 26              Sajib Das      5
# 27            Akash  Deep      5
# 28         Bhaskar Sharma      5
# 29      Flipkart Customer      5
#
#                                                REVIEW  \
# 0   Just go for it.Amazing one.Beautiful camera wi...
# 1                                High quality camera😍
# 2   Totally happy!Camera 5Battery 5 Display 5Design 5
# 3                                           Very nice
# 4   Switch from OnePlus to iPhone I am stunned wit...
# 5                Camera Quality Is Improved Loving It
# 6   Awesome photography experience. Battery backup...
# 7                                        Awesome 🔥🔥☺️
# 8           So beautiful, so elegant, just a vowww😍❤️
# 9   Awesome product very happy to hold this. Bette...
# 10                                             Nice 👌
# 11                                    Nice phone good
# 12  The iPhone 15 exceeded my expectations in ever...
# 13               Awesome camra quality superb camra 😊
# 14  Using this Iphone 15 from 1month and it has be...
# 15                                   Simply Awesome 🤩
# 16  I have recently switched from Android to ios, ...
# 17  This is my first iphone ever used loving it al...
# 18  Awesome quality I am very happy. Thank you Fli...
# 19                                       Nice product
# 20                         Camera quality top notch 👍
# 21  Awesome phone powerful performance and battery...
# 22                             Simply wow wow wow 😍❤️
# 23                                         Nice 🙂🙂🙂🙂🙂
# 24                            Very nice product 👌👌👌👌👌
# 25  Their is nothing to explain about Apple iPhone...
# 26  moving from android to apple is a surreal expe...
# 27  Camera is just wow. All classes clicks are don...
# 28                                            Awesome
# 29                                           Camera 🔥
#
#                                               REVIEW1  \
# 0                     [Just go for it., Amazing one.]
# 1                                                  []
# 2                                    [Totally happy!]
# 3                                                  []
# 4   [Switch from OnePlus to iPhone I am stunned wi...
# 5                                                  []
# 6   [Awesome photography experience.,  Battery bac...
# 7                                                  []
# 8                                                  []
# 9   [Awesome product very happy to hold this.,  Be...
# 10                                                 []
# 11                                                 []
# 12  [The iPhone 15 exceeded my expectations in eve...
# 13                                                 []
# 14                                                 []
# 15                                                 []
# 16  [I have recently switched from Android to ios,...
# 17                                                 []
# 18  [Awesome quality I am very happy.,  Thank you ...
# 19                                                 []
# 20                                                 []
# 21                                                 []
# 22                                                 []
# 23                                                 []
# 24                                                 []
# 25                                                 []
# 26  [moving from android to apple is a surreal exp...
# 27  [Camera is just wow.,  All classes clicks are ...
# 28                                                 []
# 29                                                 []
#
#                                           Polarity  Subjectivity  \
# 0                        [0.0, 0.6000000000000001]      0.633333
# 1                                               []      0.540000
# 2                                            [1.0]      0.750000
# 3                                               []      1.000000
# 4                                       [0.0, 1.0]      1.000000
# 5                                               []      0.950000
# 6                                  [1.0, 0.7, 0.5]      0.700000
# 7                                               []      1.000000
# 8                                               []      1.000000
# 9   [1.0, 0.5, 0.5, 0.0, -0.1, 0.6666666666666666]      0.557407
# 10                                              []      1.000000
# 11                                              []      0.800000
# 12                       [0.0, 0.5, 0.9, 0.5, 0.5]      0.792857
# 13                                              []      1.000000
# 14                                              []      0.300000
# 15                                              []      1.000000
# 16                [0.23833333333333337, 0.78, 0.5]      0.689000
# 17                                              []      0.461111
# 18                                      [1.0, 0.0]      1.000000
# 19                                              []      1.000000
# 20                                              []      0.500000
# 21                                              []      0.926667
# 22                                              []      1.000000
# 23                                              []      1.000000
# 24                                              []      1.000000
# 25                                              []      0.900000
# 26                                     [0.25, 0.5]      0.750000
# 27                            [0.1, 0.0, 1.0, 0.0]      0.733333
# 28                                              []      1.000000
# 29                                              []      0.000000
#
#     Average_Polarity           Sentiment
# 0           0.300000            Positive
# 1           0.000000             Neutral
# 2           1.000000  Extremely Positive
# 3           0.000000             Neutral
# 4           0.500000            Positive
# 5           0.000000             Neutral
# 6           0.733333            Positive
# 7           0.000000             Neutral
# 8           0.000000             Neutral
# 9           0.427778            Positive
# 10          0.000000             Neutral
# 11          0.000000             Neutral
# 12          0.480000            Positive
# 13          0.000000             Neutral
# 14          0.000000             Neutral
# 15          0.000000             Neutral
# 16          0.506111            Positive
# 17          0.000000             Neutral
# 18          0.500000            Positive
# 19          0.000000             Neutral
# 20          0.000000             Neutral
# 21          0.000000             Neutral
# 22          0.000000             Neutral
# 23          0.000000             Neutral
# 24          0.000000             Neutral
# 25          0.000000             Neutral
# 26          0.375000            Positive
# 27          0.275000            Positive
# 28          0.000000             Neutral
# 29          0.000000             Neutral

# %%
pol = df["Average_Polarity"].mean()

# %%
if pol <= -0.6:
    print("Extremely Negative")
elif pol <= -0.2:
    print("Negative")
elif pol <0.2:
    print("Neutral")
elif pol <= 0.6:
    print("Positive")
else:
    print("Extremely Positive")
# Out:
# Neutral
